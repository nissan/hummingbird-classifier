# %% [markdown]
# ## Hummingbird dataset from Google Images - using Resnet34
# *by Nissan Dookeran*
#
# *based on original lesson 2 by: Francisco Ingham and Jeremy Howard. Inspired by [Adrian Rosebrock](https://www.pyimagesearch.com/2017/12/04/how-to-create-a-deep-learning-dataset-using-google-images/)*

# %% [markdown]
# In this notebook I use a created image dataset from Google Images using the technique described in the Downloads notebook that consisted of species of hummingbirds commonly found in Trinidad and Tobago. The initial run was as good as the [test done previously](https://gist.github.com/nissan/a225e6cf1a87ecde69f7eb78e30de163) on [Bird Species](http://www.vision.caltech.edu/visipedia/CUB-200-2011.html) dataset at around 25% error rate when I had only 3 species categorised but resulted in very poor performance (around 50% error rate) when more species were added.
#
# Analysis of the data indicated that while most of the images retrieved were always hummingbirds, the species of images wwas sometimes incorrect so there was a mismatch between the keyword search and the image dataset retrieved thru Google Images. The first step was for the wrongly matched species of hummingbird to be deleted from these folders.
#
# Additionally, for some species, physical traits of male and females of each species were varied, and this too I make a guess that this may be the source of the issue with the classifier's misclassifications, so at the very least, separating by gender could indicate if mismatches were because of confusion between specific genders of specific species and not the two species in general.
#
# So images for species were manually divided into male and female images and placed in separate category folders based on a little research done into what the traits were that distinguished the male and female of a species of hummingbird. Sometimes these traits were very small or not distinguishable, so for these species no segmentation by gender was done. This notebook runs with this data cleanup and new separations to evaluate if performance improved with this.

# %% [markdown]
# ## Setup datasets

# %% [markdown]
# ### Initialization of data, cleanup any bad images still around

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai import *
from fastai.vision import *

# %%
bs = 16
size=224
path = Path('data/h3')

# %% [markdown]
# Good! Let's take a look at some of our pictures then.

# %%
classes = ['ruby_topaz_female',
           'ruby_topaz_male',
           'black_throated_mango_female',
           'black_throated_mango_male',
           'blue_chinned_sapphire_female',
           'blue_chinned_sapphire_male',
           'blue_tailed_emerald_female',
           'blue_tailed_emerald_male',
           'brown_violetear',
           'copper_rumped',
           'green_throated_mango',
           'long_billed_starthroat',
           'tufted_coquette_female',
           'tufted_coquette_male',
           'white_chested_emerald',
           'green_hermit_male',
           'green_hermit_female',
           'little_hermit',
           'rufous_breasted_hermit',
           'white_necked_jacobin_female',
           'white_necked_jacobin_male',
           'white_tailed_goldenthroat',
           'white_tailed_sabrewing'
          ]

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_workers=8)
# Out:
# ruby_topaz_female
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='31' class='' max='31', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [31/31 00:00<00:00]
#     </div>
# ruby_topaz_male
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='144' class='' max='144', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [144/144 00:00<00:00]
#     </div>
# black_throated_mango_female
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='79' class='' max='79', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [79/79 00:00<00:00]
#     </div>
# black_throated_mango_male
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='88' class='' max='88', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [88/88 00:00<00:00]
#     </div>
# blue_chinned_sapphire_female
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='34' class='' max='34', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [34/34 00:00<00:00]
#     </div>
# blue_chinned_sapphire_male
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='110' class='' max='110', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [110/110 00:00<00:00]
#     </div>
# blue_tailed_emerald_female
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='44' class='' max='44', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [44/44 00:00<00:00]
#     </div>
# blue_tailed_emerald_male
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='121' class='' max='121', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [121/121 00:00<00:00]
#     </div>
# brown_violetear
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='144' class='' max='144', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [144/144 00:00<00:00]
#     </div>
# copper_rumped
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='175' class='' max='175', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [175/175 00:00<00:00]
#     </div>
# green_throated_mango
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='58' class='' max='58', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [58/58 00:00<00:00]
#     </div>
# long_billed_starthroat
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='155' class='' max='155', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [155/155 00:00<00:00]
#     </div>
# tufted_coquette_female
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='33' class='' max='33', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [33/33 00:00<00:00]
#     </div>
# tufted_coquette_male
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='120' class='' max='120', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [120/120 00:00<00:00]
#     </div>
# white_chested_emerald
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='160' class='' max='160', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [160/160 00:00<00:00]
#     </div>
# green_hermit_male
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='58' class='' max='58', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [58/58 00:00<00:00]
#     </div>
# green_hermit_female
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='78' class='' max='78', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [78/78 00:00<00:00]
#     </div>
# little_hermit
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='107' class='' max='107', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [107/107 00:00<00:00]
#     </div>
# rufous_breasted_hermit
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='129' class='' max='129', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [129/129 00:00<00:00]
#     </div>
# white_necked_jacobin_female
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='29' class='' max='29', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [29/29 00:00<00:00]
#     </div>
# white_necked_jacobin_male
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='143' class='' max='143', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [143/143 00:00<00:00]
#     </div>
# white_tailed_goldenthroat
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='83' class='' max='83', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [83/83 00:00<00:00]
#     </div>
# white_tailed_sabrewing
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='106' class='' max='106', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [106/106 00:00<00:00]
#     </div>

# %% [markdown]
# ## View data

# %%
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,bs=bs, size=size,
        ds_tfms=get_transforms(), num_workers=4).normalize(imagenet_stats)

# %%
data.classes
# Out:
# ['black_throated_mango_female',
#  'black_throated_mango_male',
#  'blue_chinned_sapphire_female',
#  'blue_chinned_sapphire_male',
#  'blue_tailed_emerald_female',
#  'blue_tailed_emerald_male',
#  'brown_violetear',
#  'copper_rumped',
#  'green_hermit_female',
#  'green_hermit_male',
#  'green_throated_mango',
#  'little_hermit',
#  'long_billed_starthroat',
#  'ruby_topaz_female',
#  'ruby_topaz_male',
#  'rufous_breasted_hermit',
#  'tufted_coquette_female',
#  'tufted_coquette_male',
#  'white_chested_emerald',
#  'white_necked_jacobin_female',
#  'white_necked_jacobin_male',
#  'white_tailed_goldenthroat',
#  'white_tailed_sabrewing']

# %%
data.show_batch(rows=3, figsize=(7,8))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['black_throated_mango_female',
#   'black_throated_mango_male',
#   'blue_chinned_sapphire_female',
#   'blue_chinned_sapphire_male',
#   'blue_tailed_emerald_female',
#   'blue_tailed_emerald_male',
#   'brown_violetear',
#   'copper_rumped',
#   'green_hermit_female',
#   'green_hermit_male',
#   'green_throated_mango',
#   'little_hermit',
#   'long_billed_starthroat',
#   'ruby_topaz_female',
#   'ruby_topaz_male',
#   'rufous_breasted_hermit',
#   'tufted_coquette_female',
#   'tufted_coquette_male',
#   'white_chested_emerald',
#   'white_necked_jacobin_female',
#   'white_necked_jacobin_male',
#   'white_tailed_goldenthroat',
#   'white_tailed_sabrewing'],
#  23,
#  1758,
#  471)

# %% [markdown]
# ## Train model

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(10)
# Out:
# Total time: 04:32
# epoch  train_loss  valid_loss  error_rate
# 1      2.724349    1.870425    0.515924    (00:29)
# 2      1.804340    1.281346    0.399151    (00:27)
# 3      1.356096    1.070448    0.348195    (00:26)
# 4      1.194495    1.046247    0.318471    (00:27)
# 5      0.977676    1.060371    0.322718    (00:27)
# 6      0.830218    0.995989    0.314225    (00:26)
# 7      0.703262    0.949119    0.303609    (00:27)
# 8      0.601845    0.941394    0.303609    (00:26)
# 9      0.560038    0.937898    0.288747    (00:27)
# 10     0.526816    0.953163    0.301486    (00:26)

# %%
learn.save('stage-1-34_3')

# %%
learn.load('stage-1-34_3')

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# LR Finder complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(6, max_lr=slice(1e-5,1e-4))
# Out:
# Total time: 02:55
# epoch  train_loss  valid_loss  error_rate
# 1      0.520234    0.915342    0.276008    (00:28)
# 2      0.527312    0.977683    0.288747    (00:31)
# 3      0.469718    0.936621    0.263270    (00:28)
# 4      0.362350    0.890289    0.280255    (00:28)
# 5      0.331459    0.843748    0.265393    (00:29)
# 6      0.301828    0.814666    0.254777    (00:29)

# %%
learn.save('stage-2-34_3')

# %%
learn.recorder.plot_losses()

# %% [markdown]
# ## Interpretation

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %%
interp.plot_top_losses(4)

# %%
interp.most_confused(min_val=2)
# Out:
# [('blue_chinned_sapphire_male', 'blue_tailed_emerald_male', 7),
#  ('black_throated_mango_female', 'green_throated_mango', 5),
#  ('blue_tailed_emerald_male', 'blue_chinned_sapphire_male', 4),
#  ('green_throated_mango', 'black_throated_mango_female', 4),
#  ('blue_tailed_emerald_female', 'blue_chinned_sapphire_female', 3),
#  ('blue_tailed_emerald_male', 'copper_rumped', 3),
#  ('green_hermit_female', 'green_hermit_male', 3),
#  ('green_hermit_male', 'green_hermit_female', 3),
#  ('rufous_breasted_hermit', 'little_hermit', 3)]

# %% [markdown]
# #### Performance with ResNet34 gives an error rate of about 26% comparible to (but not quite that of) training on the bird species dataset.

# %% [markdown]
# Notes: In researching literature on Hummingbird species, it was noted that green throated mangos and black throated mangos are often confused by humans as well in real world nature observations. Additionally male and female confusions are common for some species are also common with human observers. So on anacdotal evidence only the model can be said to not be doing too badly when compared to human recognition.
